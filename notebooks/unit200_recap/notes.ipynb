# %% [markdown]
# # Python basics
#
# - strings, integers, floats, lists
# - built-in functions and methods (like what, concretely?)

# %% [markdown]
# # More Python basics
#
# - custom functions
#     - arguments
#     - return (vs print)
#     - docstrings
#     - type annotation
# - for loop
# - Counters
#     - most_common
#     - using keys
#     - .values
# - set
#     - not covered: set methods
# - list/set comprehensions
#
# - more library loading
#     - import as
#     - from import
#
# - ternary if
# - one-line return
#
# - working with strings
#     - lower, upper, title
#     - not covered: startswith, endswith, join, split
#
# - working with strings/lists
#     - indices
#     - slices
#     - len
#     - sum
#     - not covered: strides
#
# - regular expressions
#     - re.sub
#     - re.findall
#     - patterns: alternatives with [ ], +, \w, \W, \s, \S, \d, \D, grouping with ( )
#     - not covered: re.find, re.match, re.split, advanced flags, check Pythex for notation
#
# - augmented assignments
#
# - working with files
#     - download
#     - read
#     - write
#     - encoding
#
# - pprint

# %% [markdown]
# # To be covered later
#
# - pass
# - dictionaries
#     - .get
#     - defaults
#     - DefaultDictionary
#     - OrderedDictionary
# - unpacking
# - recursive functions
# - decorators [ex]
# - exception handling [ex]
# - break/continue
# - pair assignments
# - set methods
# - for else [ex]
# - unit tests with hypothesis and pytest
# - OOP
#     - classes
#     - attributes
#     - methods
#     - operator overloading [ex]
# - traps and common mistakes with variables
# - lambda
# - sorted (with key)
# - range
# - regex
#     - ^, $, [^ ], |, flags
# - mutable VS immutable
#     - strings VS nothing
#     - tuples VS lists
#     - sets VS frozensets
# - pandas
# - scikit-learn
# - nltk
# - tensorflow
# - generators VS
# - functions
#     - keyword arguments
#     - default arguments
#     - yield for generators [ex]
# - references VS copies VS deep copies
# - zip
